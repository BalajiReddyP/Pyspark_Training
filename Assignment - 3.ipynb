# %%
sc
# Out:
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="/?o=1257058777180472#setting/sparkui/0906-112158-y1h86bm0/driver-2821032980092563026">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.2.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[8]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Databricks Shell</code></dd>
#             </dl>
#         </div>

# %%
print(spark)
from pyspark.sql.functions import *

# %% [markdown]
# #a)	Create HR_Employee Pysaprk dataFrame.

# %%
HR_Employee_df = spark.read.csv("dbfs:/FileStore/tables/HR_Employee.csv",header = True, inferSchema = True)
type(HR_Employee_df)
# Out:
# Out[7]: pyspark.sql.dataframe.DataFrame

# %% [markdown]
# #b)	Show printSchema & show 10 rows of Dataset

# %%
HR_Employee_df.printSchema()
HR_Employee_df.show(10)
# Out:
# root
#  |-- EmployeeID: integer (nullable = true)
#  |-- Department: string (nullable = true)
#  |-- JobRole: string (nullable = true)
#  |-- Attrition: string (nullable = true)
#  |-- Gender: string (nullable = true)
#  |-- Age: integer (nullable = true)
#  |-- MaritalStatus: string (nullable = true)
#  |-- Education: string (nullable = true)
#  |-- EducationField: string (nullable = true)
#  |-- BusinessTravel: string (nullable = true)
#  |-- JobInvolvement: string (nullable = true)
#  |-- JobLevel: integer (nullable = true)
#  |-- JobSatisfaction: string (nullable = true)
#  |-- Hourlyrate: integer (nullable = true)
#  |-- Income: integer (nullable = true)
#  |-- Salaryhike: integer (nullable = true)
#  |-- OverTime: string (nullable = true)
#  |-- Workex: integer (nullable = true)
#  |-- YearsSinceLastPromotion: integer (nullable = true)
#  |-- EmpSatisfaction: string (nullable = true)
#  |-- TrainingTimesLastYear: integer (nullable = true)
# ...

# %% [markdown]
# #c)	Most employee is working in which department

# %%
HR_Employee_df.createOrReplaceTempView("HR_Data")

spark.sql("select Department,count(EmployeeID) as Total from HR_Data group by Department order by Total desc limit 1").show()
# Out:
# +--------------------+-----+
# |          Department|Total|
# +--------------------+-----+
# |Research & Develo...|  961|
# +--------------------+-----+

# %% [markdown]
# #d)	Highest number of job roles

# %%
spark.sql("select JobRole,count(JobRole) as number from HR_Data group by JobRole order by number desc limit 1").show()
# Out:
# +---------------+------+
# |        JobRole|number|
# +---------------+------+
# |Sales Executive|   326|
# +---------------+------+

# %% [markdown]
# #e)	Which gender have higher strength as workforce?

# %%
spark.sql("select Gender, count(Gender) as number from HR_Data group by Gender order by number desc limit 1").show()
# Out:
# +------+------+
# |Gender|number|
# +------+------+
# |  Male|   881|
# +------+------+

# %% [markdown]
# #f)	Compare the marital status of employee and find the most frequent status.

# %%
spark.sql("select MaritalStatus, count(MaritalStatus) as number from HR_Data group by MaritalStatus order by number desc ").show()
# Out:
# +-------------+------+
# |MaritalStatus|number|
# +-------------+------+
# |      Married|   672|
# |       Single|   470|
# |     Divorced|   327|
# +-------------+------+

# %% [markdown]
# #g)	Mostly hired employee have qualification

# %%
spark.sql("select Education, count(Education) as number from HR_Data group by Education order by number desc").show()
# Out:
# +-------------+------+
# |    Education|number|
# +-------------+------+
# |     Bachelor|   572|
# |       Master|   398|
# |      College|   282|
# |Below College|   169|
# |       Doctor|    48|
# +-------------+------+

# %%
spark.sql("select EducationField,count(EducationField) as number from HR_Data group by EducationField order by number desc").show()
# Out:
# +----------------+------+
# |  EducationField|number|
# +----------------+------+
# |   Life Sciences|   605|
# |         Medical|   464|
# |       Marketing|   159|
# |Technical Degree|   132|
# |           Other|    82|
# | Human Resources|    27|
# +----------------+------+

# %% [markdown]
# #i)	What is the job satisfaction level of employee?

# %%
spark.sql("select JobSatisfaction, count(JobSatisfaction) as number from HR_Data group by JobSatisfaction order by number").show()
# Out:
# +---------------+------+
# |JobSatisfaction|number|
# +---------------+------+
# |         Medium|   280|
# |            Low|   289|
# |           High|   441|
# |      Very High|   459|
# +---------------+------+

# %% [markdown]
# #j)	Does most of employee do overtime: Yes or No?

# %%
spark.sql("select OverTime, count(OverTime) as total from HR_Data group by OverTime order by total desc ").show()
# Out:
# +--------+-----+
# |OverTime|total|
# +--------+-----+
# |      No| 1053|
# |     Yes|  416|
# +--------+-----+

# %% [markdown]
# #k)	Find Min & Max Salaried employees.

# %%
HR_Employee_df.select(max('Income') , min('Income')).show()
# Out:
# +-----------+-----------+
# |max(Income)|min(Income)|
# +-----------+-----------+
# |      19999|       1009|
# +-----------+-----------+

# %% [markdown]
# #l)	Does most of the employee do business travel? Find of the employees counts for each category

# %%
spark.sql("select BusinessTravel,count(BusinessTravel) as Emp_count from HR_Data group by BusinessTravel order by Emp_count desc ").show()
# Out:
# +-----------------+---------+
# |   BusinessTravel|Emp_count|
# +-----------------+---------+
# |    Travel_Rarely|     1042|
# |Travel_Frequently|      277|
# |       Non-Travel|      150|
# +-----------------+---------+

# %% [markdown]
# #m)	Find the AVG salary of graduate employee.

# %%
HR_Employee_df.select(avg(when(HR_Employee_df['Education'] == 'Bachelor',HR_Employee_df['Income'])).alias("avg_Income_grad")).show()
# Out:
# +-----------------+
# |  avg_Income_grad|
# +-----------------+
# |6517.263986013986|
# +-----------------+

# %% [markdown]
# #n)	Find the employee qualification receiving salary lower than equal to avg. salary of all employee.

# %%
spark.sql("select EmployeeID,Education,Income from HR_Data where Income < (select avg(Income) from HR_Data) ").show()
# Out:
# +----------+-------------+------+
# |EmployeeID|    Education|Income|
# +----------+-------------+------+
# |         1|      College|  5993|
# |         2|Below College|  5130|
# |         3|      College|  2090|
# |         4|       Master|  2909|
# |         5|Below College|  3468|
# |         6|      College|  3068|
# |         7|     Bachelor|  2670|
# |         8|Below College|  2693|
# |        10|     Bachelor|  5237|
# |        11|     Bachelor|  2426|
# |        12|      College|  4193|
# |        13|Below College|  2911|
# |        14|      College|  2661|
# |        15|     Bachelor|  2028|
# |        17|      College|  3298|
# |        18|      College|  2935|
# |        20|     Bachelor|  3944|
# |        21|      College|  4011|
# |        22|       Master|  3407|
# |        24|      College|  1232|
# +----------+-------------+------+
# only showing top 20 rows

# %% [markdown]
# #o)	When does the employee have highest chance of promotion in terms of working year?

# %%
# Did'nt get the answer to this question

# %% [markdown]
# #p)	Highest attrition is in which department?

# %%
spark.sql("select Department,count(Department)as att_number from HR_Data where Attrition = 'Yes' group by Department order by att_number desc ").show()
# Out:
# +--------------------+----------+
# |          Department|att_number|
# +--------------------+----------+
# |Research & Develo...|       133|
# |               Sales|        92|
# |     Human Resources|        12|
# +--------------------+----------+

# %% [markdown]
# #q)	Show marital status of Person having highest attrition rate

# %%
spark.sql("select MaritalStatus,count(MaritalStatus) as Total from HR_Data where Attrition = 'Yes' group by MaritalStatus order by Total desc ").show()
# Out:
# +-------------+-----+
# |MaritalStatus|Total|
# +-------------+-----+
# |       Single|  120|
# |      Married|   84|
# |     Divorced|   33|
# +-------------+-----+
